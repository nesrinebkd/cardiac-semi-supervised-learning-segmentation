# %% [markdown]
# ### Install requirements

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install batchgenerators
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 9.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 17.1 MB/s eta 0:00:00
# ...
#   Created wheel for batchgenerators: filename=batchgenerators-0.25.1-py3-none-any.whl size=93088 sha256=784cf33ac8527cd7ec27560e3f229f8ed5eac762c6c3d8c70614077c31183818
#   Stored in directory: /root/.cache/pip/wheels/28/21/2b/7b25080f9f5847e6c3162b89d859d7cec9f3093158e56bd008
# Successfully built batchgenerators
# ...

# %%
# !pip install tensorboardX
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 9.5 MB/s eta 0:00:00
# ...

# %%
# !pip install medpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.3/156.3 kB 20.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 MB 50.6 MB/s eta 0:00:00
# ...
#   Created wheel for medpy: filename=MedPy-0.5.2-py3-none-any.whl size=224710 sha256=3d993a0e3957e5b80770b34294d12e215172c60470875adc0bd5ef25ff277a45
#   Stored in directory: /root/.cache/pip/wheels/89/5a/f8/b3def53b9c2133d2f8698ea2173bb5df63bd8e761ce8e9aec9
# Successfully built medpy
# ...

# %%
# !pip install efficientnet_pytorch
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for efficientnet_pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16426 sha256=c9e0ce0dbfbd4c0cea3d9e8946fe40917207c909367efa4c1f731dfd827b3de6
#   Stored in directory: /root/.cache/pip/wheels/9c/3f/43/e6271c7026fe08c185da2be23c98c8e87477d3db63f41f32ad
# Successfully built efficientnet_pytorch
# ...

# %%
# !pip install yacs

# %%
import torch
print(torch.version.cuda)         # version de CUDA supportée par PyTorch
print(torch.cuda.is_available())
# Out:
# 12.8
# True

# %% [markdown]
# ### GAN - 14 Patients

# %% [markdown]
# #### Train model

# %%
# %cd /content/drive/MyDrive/prj/Project_ind/ACDC/SSL4MIS-master/SSL4MIS-master/code
# Out:
# /content/drive/.shortcut-targets-by-id/1vsyJDW9ILzHHhEeKu3Af6AwF8FiSnpp6/Project_ind/ACDC/SSL4MIS-master/SSL4MIS-master/code

# %%
# !python train_adversarial_network_2D.py \
  --root_path /content/drive/MyDrive/prj/Project_ind/ACDC/ACDC_preprocessed \
  --exp ACDC/Adversarial_Network \
  --num_classes 4 \
  --labeled_num 14 \
  --model efficient_unet \
  --batch_size 8 \
  --labeled_bs 4 \
  --max_iterations 10000
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# iteration 5029 : loss : 0.028732, loss_ce: 0.011468, loss_dice: 0.034826
# iteration 5030 : loss : 0.044021, loss_ce: 0.010716, loss_dice: 0.065771
# iteration 5031 : loss : 0.029598, loss_ce: 0.010291, loss_dice: 0.043176
# iteration 5032 : loss : 0.031152, loss_ce: 0.012571, loss_dice: 0.039547
# iteration 5033 : loss : 0.027086, loss_ce: 0.010261, loss_dice: 0.030660
# iteration 5034 : loss : 0.030671, loss_ce: 0.011235, loss_dice: 0.043919
# iteration 5035 : loss : 0.030217, loss_ce: 0.011794, loss_dice: 0.038992
# iteration 5036 : loss : 0.027628, loss_ce: 0.012243, loss_dice: 0.033415
# iteration 5037 : loss : 0.030317, loss_ce: 0.015070, loss_dice: 0.036510
# iteration 5038 : loss : 0.029923, loss_ce: 0.011485, loss_dice: 0.035464
# iteration 5039 : loss : 0.035515, loss_ce: 0.015166, loss_dice: 0.042504
# iteration 5040 : loss : 0.031890, loss_ce: 0.016182, loss_dice: 0.036562
# ...

# %%
# !python test_2D_fully.py \
  --root_path /content/drive/MyDrive/prj/Project_ind/ACDC/ACDC_preprocessed \
  --exp ACDC/Adversarial_Network \
  --num_classes 4 \
  --model efficient_unet \
  --labeled_num 14
# Out:
# /content/drive/.shortcut-targets-by-id/1vsyJDW9ILzHHhEeKu3Af6AwF8FiSnpp6/Project_ind/ACDC/SSL4MIS-master/SSL4MIS-master/code/test_2D_fully.py:12: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.ndimage.interpolation import zoom
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# => merge config from ../code/configs/swin_tiny_patch4_window7_224_lite.yaml
# init weight from ../model/ACDC/Adversarial_Network_14_labeled/efficient_unet/efficient_unet_best_model.pth
# 100% 100/100 [02:57<00:00,  1.77s/it]
# ...

# %% [markdown]
# ### GAN - 7 patients

# %% [markdown]
# #### Train model

# %%
# !python train_adversarial_network_2D.py \
  --root_path /content/drive/MyDrive/prj/Project_ind/ACDC/ACDC_preprocessed \
  --exp ACDC/Adversarial_Network \
  --num_classes 4 \
  --labeled_num 7 \
  --model efficient_unet \
  --batch_size 8 \
  --labeled_bs 4 \
  --max_iterations 10000
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# iteration 5029 : loss : 0.030912, loss_ce: 0.008505, loss_dice: 0.036449
# iteration 5030 : loss : 0.028668, loss_ce: 0.010171, loss_dice: 0.037138
# iteration 5031 : loss : 0.032003, loss_ce: 0.006956, loss_dice: 0.041467
# iteration 5032 : loss : 0.028233, loss_ce: 0.008580, loss_dice: 0.038668
#  50%|███████████████▌               | 148/295 [10:18<14:59,  6.12s/it]iteration 5033 : loss : 0.029101, loss_ce: 0.010425, loss_dice: 0.033839
# iteration 5034 : loss : 0.031616, loss_ce: 0.014287, loss_dice: 0.035855
# iteration 5035 : loss : 0.029079, loss_ce: 0.011404, loss_dice: 0.034490
# iteration 5036 : loss : 0.029865, loss_ce: 0.008832, loss_dice: 0.037469
# iteration 5037 : loss : 0.031449, loss_ce: 0.010593, loss_dice: 0.042056
# iteration 5038 : loss : 0.051738, loss_ce: 0.014054, loss_dice: 0.083108
# iteration 5039 : loss : 0.032358, loss_ce: 0.011188, loss_dice: 0.037705
# ...

# %% [markdown]
# #### Test Model

# %%
# !python test_2D_fully.py \
  --root_path /content/drive/MyDrive/prj/Project_ind/ACDC/ACDC_preprocessed \
  --exp ACDC/Adversarial_Network \
  --num_classes 4 \
  --model efficient_unet \
  --labeled_num 7
# Out:
# /content/drive/.shortcut-targets-by-id/1vsyJDW9ILzHHhEeKu3Af6AwF8FiSnpp6/Project_ind/ACDC/SSL4MIS-master/SSL4MIS-master/code/test_2D_fully.py:12: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.ndimage.interpolation import zoom
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# => merge config from ../code/configs/swin_tiny_patch4_window7_224_lite.yaml
# init weight from ../model/ACDC/Adversarial_Network_7_labeled/efficient_unet/efficient_unet_best_model.pth
# 100% 100/100 [00:49<00:00,  2.03it/s]
# ...
