# %% [markdown]
# #### Test with small number of iterations ( doesn't work )

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorboardX
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 4.4 MB/s eta 0:00:00
# ...

# %%
# !pip install batchgenerators
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 3.9 MB/s eta 0:00:00
# ...
#   Created wheel for batchgenerators: filename=batchgenerators-0.25.1-py3-none-any.whl size=93088 sha256=e61df7208b577372d4c3efe02c5ed8208d18f77c102f1a77a0da40e06239a6bc
#   Stored in directory: /root/.cache/pip/wheels/28/21/2b/7b25080f9f5847e6c3162b89d859d7cec9f3093158e56bd008
# Successfully built batchgenerators
# ...

# %%
# !pip install medpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.3/156.3 kB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 MB 15.2 MB/s eta 0:00:00
# ...
#   Created wheel for medpy: filename=MedPy-0.5.2-py3-none-any.whl size=224710 sha256=e218e5c101c9cee34a97ba297e31cfa4a978ab55d6c95651c000aaf5ec9a32f4
#   Stored in directory: /root/.cache/pip/wheels/89/5a/f8/b3def53b9c2133d2f8698ea2173bb5df63bd8e761ce8e9aec9
# Successfully built medpy
# ...

# %%
# !pip install efficientnet_pytorch
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for efficientnet_pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16426 sha256=20700aef1dfc71bb7fb19da6309b1d78148532f19d012bc00fc004a90434c3d7
#   Stored in directory: /root/.cache/pip/wheels/9c/3f/43/e6271c7026fe08c185da2be23c98c8e87477d3db63f41f32ad
# Successfully built efficientnet_pytorch
# ...

# %%
# !pip install yacs

# %%
import torch
print(torch.version.cuda)         # version de CUDA supportée par PyTorch
print(torch.cuda.is_available())
# Out:
# None
# False

# %%
# %cd /content/drive/MyDrive/Project_ind/ACDC/SSL4MIS-master
# Out:
# /content/drive/MyDrive/Project_ind/ACDC/SSL4MIS-master

# %%
# %cd /content/drive/MyDrive/Project_ind/ACDC/SSL4MIS-master/SSL4MIS-master/code
# Out:
# /content/drive/MyDrive/Project_ind/ACDC/SSL4MIS-master/SSL4MIS-master/code

# %%
# !python train_fully_supervised_2D.py \
  --root_path /content/drive/MyDrive/Project_ind/ACDC/ACDC_preprocessed \
  --exp ACDC/Fully_Supervised \
  --num_classes 4 \
  --labeled_num 7 \
  --batch_size 8 \
  --max_iterations 3000
# Out:
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# => merge config from ../code/configs/swin_tiny_patch4_window7_224_lite.yaml
# Namespace(root_path='/content/drive/MyDrive/Project_ind/ACDC/ACDC_preprocessed', exp='ACDC/Fully_Supervised', model='unet', num_classes=4, max_iterations=3000, batch_size=8, deterministic=1, base_lr=0.01, patch_size=[256, 256], seed=1337, labeled_num=7)
# total 136 samples
# total 40 samples
# ...

# %%
# !python test_2D_fully.py \
  --root_path /content/drive/MyDrive/Project_ind/ACDC/ACDC_preprocessed \
  --exp ACDC/Fully_Supervised \
  --model unet \
  --num_classes 4 \
  --labeled_num 7
# Out:
# /content/drive/MyDrive/Project_ind/ACDC/SSL4MIS-master/SSL4MIS-master/code/test_2D_fully.py:12: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.ndimage.interpolation import zoom
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# => merge config from ../code/configs/swin_tiny_patch4_window7_224_lite.yaml
# init weight from ../model/ACDC/Fully_Supervised_7_labeled/unet/unet_best_model.pth
#   2% 2/100 [00:03<03:09,  1.93s/it]
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Project_ind/ACDC/SSL4MIS-master/SSL4MIS-master/code/test_2D_fully.py", line 115, in <module>
#     metric = Inference(FLAGS)
# ...

# %%
# !python train_fully_supervised_2D.py \
  --root_path /content/drive/MyDrive/Project_ind/ACDC/ACDC_preprocessed \
  --exp ACDC/Fully_Supervised \
  --num_classes 4 \
  --labeled_num 14 \
  --batch_size 8 \
  --max_iterations 3000
# Out:
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# => merge config from ../code/configs/swin_tiny_patch4_window7_224_lite.yaml
# Namespace(root_path='/content/drive/MyDrive/Project_ind/ACDC/ACDC_preprocessed', exp='ACDC/Fully_Supervised', model='unet', num_classes=4, max_iterations=3000, batch_size=8, deterministic=1, base_lr=0.01, patch_size=[256, 256], seed=1337, labeled_num=14)
# total 256 samples
# total 40 samples
# ...

# %%
# !python test_2D_fully.py \
  --root_path /content/drive/MyDrive/Project_ind/ACDC/ACDC_preprocessed \
  --exp ACDC/Fully_Supervised \
  --model unet \
  --num_classes 4 \
  --labeled_num 14
# Out:
# /content/drive/MyDrive/Project_ind/ACDC/SSL4MIS-master/SSL4MIS-master/code/test_2D_fully.py:12: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.ndimage.interpolation import zoom
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# => merge config from ../code/configs/swin_tiny_patch4_window7_224_lite.yaml
# init weight from ../model/ACDC/Fully_Supervised_14_labeled/unet/unet_best_model.pth
#   3% 3/100 [00:03<01:45,  1.09s/it]
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Project_ind/ACDC/SSL4MIS-master/SSL4MIS-master/code/test_2D_fully.py", line 115, in <module>
#     metric = Inference(FLAGS)
# ...

# %%
# !python train_fully_supervised_2D.py \
  --root_path /content/drive/MyDrive/Project_ind/ACDC/ACDC_preprocessed \
  --exp ACDC/Fully_Supervised \
  --num_classes 4 \
  --labeled_num 7 \
  --batch_size 8 \
  --max_iterations 9000
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# iteration 4029 : loss : 0.023311, loss_ce: 0.010496, loss_dice: 0.036125
#  45%|█████████████▊                 | 237/530 [18:14<31:49,  6.52s/it]iteration 4030 : loss : 0.021752, loss_ce: 0.006969, loss_dice: 0.036534
# iteration 4031 : loss : 0.020199, loss_ce: 0.009141, loss_dice: 0.031257
# iteration 4032 : loss : 0.022117, loss_ce: 0.009428, loss_dice: 0.034806
# iteration 4033 : loss : 0.020789, loss_ce: 0.009569, loss_dice: 0.032008
# iteration 4034 : loss : 0.022056, loss_ce: 0.007806, loss_dice: 0.036306
# iteration 4035 : loss : 0.019767, loss_ce: 0.009702, loss_dice: 0.029832
# iteration 4036 : loss : 0.020702, loss_ce: 0.007742, loss_dice: 0.033661
# iteration 4037 : loss : 0.022286, loss_ce: 0.009513, loss_dice: 0.035059
# iteration 4038 : loss : 0.024279, loss_ce: 0.010804, loss_dice: 0.037754
# iteration 4039 : loss : 0.019174, loss_ce: 0.008074, loss_dice: 0.030273
# ...

# %%
# !python test_2D_fully.py \
  --root_path /content/drive/MyDrive/Project_ind/ACDC/ACDC_preprocessed \
  --exp ACDC/Fully_Supervised \
  --model unet \
  --num_classes 4 \
  --labeled_num 7
# Out:
# /content/drive/MyDrive/Project_ind/ACDC/SSL4MIS-master/SSL4MIS-master/code/test_2D_fully.py:12: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.ndimage.interpolation import zoom
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# => merge config from ../code/configs/swin_tiny_patch4_window7_224_lite.yaml
# init weight from ../model/ACDC/Fully_Supervised_7_labeled/unet/unet_best_model.pth
#   2% 2/100 [00:01<01:10,  1.38it/s]
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Project_ind/ACDC/SSL4MIS-master/SSL4MIS-master/code/test_2D_fully.py", line 115, in <module>
#     metric = Inference(FLAGS)
# ...

# %%
# !python train_fully_supervised_2D.py \
  --root_path /content/drive/MyDrive/Project_ind/ACDC/ACDC_preprocessed \
  --exp ACDC/Fully_Supervised \
  --num_classes 4 \
  --labeled_num 14 \
  --batch_size 8 \
  --max_iterations 9000
# Out:
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# => merge config from ../code/configs/swin_tiny_patch4_window7_224_lite.yaml
# Namespace(root_path='/content/drive/MyDrive/Project_ind/ACDC/ACDC_preprocessed', exp='ACDC/Fully_Supervised', model='unet', num_classes=4, max_iterations=9000, batch_size=8, deterministic=1, base_lr=0.01, patch_size=[256, 256], seed=1337, labeled_num=14)
# total 256 samples
# total 40 samples
# ...

# %% [markdown]
# #### Fully supervised learning Efficient Unet / 80 patients

# %% [markdown]
# #### Training model

# %%
# !python train_fully_supervised_2D.py \
  --root_path /content/drive/MyDrive/Project_ind/ACDC/ACDC_preprocessed \
  --exp ACDC/Fully_Supervised \
  --num_classes 4 \
  --labeled_num 80 \
  --model efficient_unet \
  --batch_size 8 \
  --max_iterations 10000
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# iteration 5029 : loss : 0.025188, loss_ce: 0.011076, loss_dice: 0.039301
# iteration 5030 : loss : 0.054283, loss_ce: 0.018680, loss_dice: 0.089886
# iteration 5031 : loss : 0.032678, loss_ce: 0.016522, loss_dice: 0.048833
# iteration 5032 : loss : 0.029531, loss_ce: 0.013992, loss_dice: 0.045069
# iteration 5033 : loss : 0.038810, loss_ce: 0.013743, loss_dice: 0.063877
# iteration 5034 : loss : 0.033237, loss_ce: 0.013107, loss_dice: 0.053367
# iteration 5035 : loss : 0.032211, loss_ce: 0.013086, loss_dice: 0.051336
# iteration 5036 : loss : 0.066188, loss_ce: 0.033621, loss_dice: 0.098754
# iteration 5037 : loss : 0.026455, loss_ce: 0.013316, loss_dice: 0.039594
# iteration 5038 : loss : 0.032503, loss_ce: 0.016214, loss_dice: 0.048792
# iteration 5039 : loss : 0.028231, loss_ce: 0.010508, loss_dice: 0.045955
# iteration 5040 : loss : 0.031268, loss_ce: 0.013446, loss_dice: 0.049089
# ...

# %% [markdown]
# #### Test model

# %%
# !python test_2D_fully.py \
  --root_path /content/drive/MyDrive/Project_ind/ACDC/ACDC_preprocessed \
  --exp ACDC/Fully_Supervised \
  --model efficient_unet \
  --num_classes 4 \
  --labeled_num 80
# Out:
# /content/drive/MyDrive/Project_ind/ACDC/SSL4MIS-master/SSL4MIS-master/code/test_2D_fully.py:12: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.ndimage.interpolation import zoom
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# => merge config from ../code/configs/swin_tiny_patch4_window7_224_lite.yaml
# init weight from ../model/ACDC/Fully_Supervised_80_labeled/efficient_unet/efficient_unet_best_model.pth
# 100% 100/100 [02:39<00:00,  1.60s/it]
# [array([0.89120193, 2.62492032, 0.86798625]), array([0.86847786, 2.03524234, 0.63005056]), array([0.92893133, 1.28161839, 0.3700997 ])]
# [0.89620371 1.98059368 0.62271217]
