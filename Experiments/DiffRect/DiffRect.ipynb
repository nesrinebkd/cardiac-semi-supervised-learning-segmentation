# %% [markdown]
# ### Install requirements

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Project_ind/ACDC/DiffRect-main/DiffRect-main
# Out:
# /content/drive/MyDrive/Project_ind/ACDC/DiffRect-main/DiffRect-main

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 MB 21.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 58.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# !pip install medpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.3/156.3 kB 16.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 MB 22.2 MB/s eta 0:00:00
# ...
#   Created wheel for medpy: filename=MedPy-0.5.2-py3-none-any.whl size=224710 sha256=45d6ed93f653cad81320ad4eceaefce1b8ddbadf22070cbd124d7ab6cbbf5515
#   Stored in directory: /root/.cache/pip/wheels/89/5a/f8/b3def53b9c2133d2f8698ea2173bb5df63bd8e761ce8e9aec9
# Successfully built medpy
# ...

# %% [markdown]
# ### DiffRect - 7 patients

# %% [markdown]
# #### Train Model

# %%
# !python train_diffrect_ACDC.py \
  --root_path /content/drive/MyDrive/Project_ind/ACDC/ACDC_preprocessed \
  --exp ACDC/DiffRect \
  --model unet \
  --num_classes 4 \
  --max_iterations 10000 \
  --batch_size 8 \
  --labeled_bs 4 \
  --labeled_num 7 \
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# iteration 5104 : mloss : 0.121410, refsupce: 0.128727, refsuplat: 0.215931, refunsupce: 0.253940, refunsuplat: 0.227070, t: 122.912231, t2: 137.684677
# iteration 5105 : mloss : 0.175491, refsupce: 0.135849, refsuplat: 0.249816, refunsupce: 0.093464, refunsuplat: 0.203160, t: 175.891998, t2: 21.920240
# iteration 5106 : mloss : 0.070829, refsupce: 0.060296, refsuplat: 0.240074, refunsupce: 0.131648, refunsuplat: 0.226341, t: 63.170441, t2: 59.361732
# iteration 5107 : mloss : 0.057026, refsupce: 0.049180, refsuplat: 0.239396, refunsupce: 0.129819, refunsuplat: 0.187893, t: 52.638424, t2: 66.621132
# iteration 5108 : mloss : 0.044868, refsupce: 0.046443, refsuplat: 0.241624, refunsupce: 0.174628, refunsuplat: 0.207478, t: 46.724354, t2: 103.812256
# iteration 5109 : mloss : 0.057414, refsupce: 0.051292, refsuplat: 0.226843, refunsupce: 0.133231, refunsuplat: 0.210152, t: 57.909397, t2: 51.394096
# ...

# %% [markdown]
# #### Test Model

# %%
# !python test_2D.py \
  --ckpt /content/drive/MyDrive/Project_ind/ACDC/DiffRect-main/DiffRect-main/logs/ACDC/DiffRect_7_labeled/unet/unet_best_model.pth \
  --root_path /content/drive/MyDrive/Project_ind/ACDC/ACDC_preprocessed \
  --model unet \
  --num_classes 4 \
  --labeled_num 7
# Out:
# /content/drive/MyDrive/Project_ind/ACDC/DiffRect-main/DiffRect-main/test_2D.py:11: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.ndimage.interpolation import zoom
# init weight from /content/drive/MyDrive/Project_ind/ACDC/DiffRect-main/DiffRect-main/logs/ACDC/DiffRect_7_labeled/unet/unet_best_model.pth
# <All keys matched successfully>
# 100% 40/40 [00:49<00:00,  1.23s/it]
# Results per class
# [array([0.80288642, 0.69849752, 2.67289923, 0.60886555]), array([0.7885703 , 0.66392194, 2.93562819, 0.97310342]), array([0.86634369, 0.79376793, 4.38381299, 1.45963226])]
#  | Dice | HD95 | Jaccard | ASD |
# Average
# [0.8192668  0.71872913 3.33078014 1.01386708]
# init weight from /content/drive/MyDrive/Project_ind/ACDC/DiffRect-main/DiffRect-main/logs/ACDC/DiffRect_7_labeled/unet/unet_best_model.pth
# <All keys matched successfully>
# ...

# %% [markdown]
# ### DiffRect - 14 patients

# %% [markdown]
# #### Train Model

# %%
# !python train_diffrect_ACDC.py \
  --root_path /content/drive/MyDrive/Project_ind/ACDC/ACDC_preprocessed \
  --exp ACDC/DiffRect \
  --model unet \
  --num_classes 4 \
  --max_iterations 10000 \
  --batch_size 8 \
  --labeled_bs 4 \
  --labeled_num 14
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# iteration 5107 : mloss : 0.073698, refsupce: 0.064105, refsuplat: 0.212484, refunsupce: 0.136258, refunsuplat: 0.178360, t: 79.402359, t2: 51.664761
# iteration 5108 : mloss : 0.072828, refsupce: 0.069047, refsuplat: 0.219263, refunsupce: 0.252720, refunsuplat: 0.280995, t: 70.811127, t2: 231.284988
# iteration 5109 : mloss : 0.085687, refsupce: 0.078303, refsuplat: 0.223594, refunsupce: 0.273868, refunsuplat: 0.207492, t: 81.960846, t2: 193.514526
# iteration 5110 : mloss : 0.084457, refsupce: 0.073639, refsuplat: 0.209745, refunsupce: 0.195825, refunsuplat: 0.222668, t: 83.091591, t2: 128.656616
# iteration 5111 : mloss : 0.066276, refsupce: 0.054042, refsuplat: 0.241623, refunsupce: 0.203341, refunsuplat: 0.225602, t: 65.979851, t2: 124.073792
# iteration 5112 : mloss : 0.065244, refsupce: 0.047261, refsuplat: 0.222218, refunsupce: 0.127007, refunsuplat: 0.221415, t: 60.339581, t2: 79.142738
# ...

# %% [markdown]
# #### Test Model

# %%
# !python test_2D.py \
  --ckpt /content/drive/MyDrive/Project_ind/ACDC/DiffRect-main/DiffRect-main/logs/ACDC/DiffRect_14_labeled/unet/unet_best_model.pth \
  --root_path /content/drive/MyDrive/Project_ind/ACDC/ACDC_preprocessed \
  --model unet \
  --num_classes 4 \
  --labeled_num 14
# Out:
# /content/drive/MyDrive/Project_ind/ACDC/DiffRect-main/DiffRect-main/test_2D.py:11: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.ndimage.interpolation import zoom
# init weight from /content/drive/MyDrive/Project_ind/ACDC/DiffRect-main/DiffRect-main/logs/ACDC/DiffRect_14_labeled/unet/unet_best_model.pth
# <All keys matched successfully>
# 100% 40/40 [00:24<00:00,  1.65it/s]
# Results per class
# [array([0.8532304 , 0.76240004, 2.0231474 , 0.69998548]), array([0.81786468, 0.70192338, 2.18642356, 0.69098107]), array([0.88096712, 0.81526169, 2.6722493 , 1.12286266])]
#  | Dice | HD95 | Jaccard | ASD |
# Average
# [0.8506874  0.7598617  2.29394009 0.83794307]
# init weight from /content/drive/MyDrive/Project_ind/ACDC/DiffRect-main/DiffRect-main/logs/ACDC/DiffRect_14_labeled/unet/unet_best_model.pth
# <All keys matched successfully>
# ...
